# %%
list(zip(*[(1,4,7), (2,5,8), (3,6,9)]))
# Out:
# [(1, 2, 3), (4, 5, 6), (7, 8, 9)]

# %%
(*[(1,4,7), (2,5,8), (3,6,9)])
# Out:
#   Cell In[7], line 1
#     (*[(1,4,7), (2,5,8), (3,6,9)])
#      ^
# SyntaxError: cannot use starred expression here
